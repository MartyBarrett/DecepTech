# %%
install librosa soundfile

# %%
import pandas as pd
import numpy as np
import os
import pickle
import librosa 
import torch
from transformers import Wav2Vec2Processor, Wav2Vec2Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score

# %%
csv_path = '../csv/utterances.csv'      # Path to your CSV file
audio_dir = '../audio_clips/'           # Folder containing .wav clips

# %%
try:
    df = pd.read_csv(csv_path)
    print(f"Loaded {len(df)} utterances from {csv_path}")
except FileNotFoundError:
    print(f"CSV file not found at {csv_path}")
# Out:
# Loaded 225 utterances from ../csv/utterances.csv

# %%
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
wav2vec_model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def extract_wave2vec_features(audio_path):
    try:
        # Load audio using librosa and resample to 16kHz
        speech, sr = librosa.load(audio_path, sr=16000)

        # Process audio through the Wav2Vec2 processor
        inputs = processor(speech, sampling_rate=16000, return_tensors="pt")
        with torch.no_grad():
            outputs = wav2vec_model(**inputs)

        # Take mean across time dimension to get a fixed-size vector
        return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

    except Exception as e:
        print(f"Error processing {audio_path}: {e}")
        return np.zeros(768)

# %%
features = []
labels = []

print(f"[INFO] Starting feature extraction from {len(df)} utterances...")

for i, (_, row) in enumerate(df.iterrows(), 1):  # start counting from 1
    audio_filename = f"{row['video_file'].replace('.mp4','')}_{int(row['start_time_ms'])}_{int(row['end_time_ms'])}.wav"
    audio_path = os.path.join(audio_dir, audio_filename)
    
    if not os.path.exists(audio_path):
        print(f"[WARNING] Missing audio file: {audio_path}")
        continue

    try:
        feat = extract_wave2vec_features(audio_path)
        features.append(feat)

        label = 1 if row['veracity'].strip().lower() == 'truthful' else 0
        labels.append(label)
        
        # Debug progress output
        print(f"[PROGRESS] Processed utterance {i}/{len(df)}: {audio_filename}")
        
    except Exception as e:
        print(f"[ERROR] Failed to extract features from {audio_path}: {e}")
        continue

features = np.array(features)
labels = np.array(labels)

if len(features) > 0:
    print(f"[INFO] Extracted {features.shape[0]} samples with shape {features.shape[1]}")
else:
    print("[ERROR] No features extracted. Please check the audio files and extraction function.")
# Out:
# [INFO] Starting feature extraction from 225 utterances...
# [PROGRESS] Processed utterance 1/225: 01_BoL_53914_70940.wav
# [PROGRESS] Processed utterance 2/225: 01_BoL_70940_72670.wav
# [PROGRESS] Processed utterance 3/225: 01_BoL_72670_100410.wav
# [PROGRESS] Processed utterance 4/225: 01_BoL_100410_104690.wav
# [PROGRESS] Processed utterance 5/225: 01_BoL_104690_127511.wav
# [PROGRESS] Processed utterance 6/225: 01_BoL_145374_188760.wav
# [PROGRESS] Processed utterance 7/225: 01_BoL_188760_191280.wav
# [PROGRESS] Processed utterance 8/225: 01_BoL_191280_195880.wav
# [PROGRESS] Processed utterance 9/225: 01_BoL_195880_205670.wav
# [PROGRESS] Processed utterance 10/225: 01_BoL_205670_226640.wav
# [PROGRESS] Processed utterance 11/225: 01_BoL_254238_344929.wav
# [PROGRESS] Processed utterance 12/225: 10_BoL_48416_78154.wav
# [PROGRESS] Processed utterance 13/225: 10_BoL_78154_96638.wav
# [PROGRESS] Processed utterance 14/225: 10_BoL_96638_112826.wav
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size=0.2, random_state=42, stratify=labels)
print("complete")
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
print("here")
y_pred = clf.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))

train_acc = accuracy_score(y_train, clf.predict(X_train))
print(f"Training Accuracy: {train_acc:.4f}")
# Out:
# complete
# here
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        28
#            1       0.77      0.67      0.71        15
#
#     accuracy                           0.81        43
#    macro avg       0.80      0.78      0.79        43
# weighted avg       0.81      0.81      0.81        43
#
# Training Accuracy: 1.0000

# %%
import pickle

# After training your model (clf), save it:
with open('deceptech_model.pkl', 'wb') as f:
    pickle.dump(clf, f)
print("Model saved!")
# Out:
# Model saved!

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, accuracy_score

# Split your data into train/test
X_trainSVM, X_testSVM, y_trainSVM, y_testSVM = train_test_split(
    features, labels, test_size=0.2, random_state=42, stratify=labels)

# Initialize Logistic Regression model with regularization
clfSVM = LogisticRegression(max_iter=1000, penalty='l2', C=1.0, random_state=42)

# Train on training data
clfSVM.fit(X_trainSVM, y_trainSVM)

# Predict and evaluate on test data
y_predSVM = clfSVM.predict(X_testSVM)
print("Classification Report:\n", classification_report(y_testSVM, y_predSVM))

train_acc = clf.score(X_trainSVM, y_trainSVM)
print(f"Training Accuracy: {train_acc:.4f}")

# Cross-validation on the full dataset (features, labels)
cv_scores = cross_val_score(clf, features, labels, cv=5)

print(f"5-Fold Cross-Validation Accuracy: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83        28
#            1       0.73      0.53      0.62        15
#
#     accuracy                           0.77        43
#    macro avg       0.75      0.71      0.72        43
# weighted avg       0.76      0.77      0.76        43
#
# Training Accuracy: 1.0000
# 5-Fold Cross-Validation Accuracy: 0.8040 ± 0.0337

# %%
# After training your logistic regression model clf
with open('deceptech_logreg_model.pkl', 'wb') as f:
    pickle.dump(clfSVM, f)

print("Logistic Regression model saved as 'deceptech_logreg_model.pkl'")
# Out:
# Logistic Regression model saved as 'deceptech_logreg_model.pkl'
